# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Real estate.csv")

# %%
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
print(df.to_string())  # .to_string make a string from csv
#CSV files contains plain text and is a well know format that can be read by everyone including Pandas.
# Out:
#       No  X1 transaction date  X2 house age  X3 distance to the nearest MRT station  X4 number of convenience stores  X5 latitude  X6 longitude  Y house price of unit area
# 0      1             2012.917          32.0                                84.87882                               10     24.98298     121.54024                        37.9
# 1      2             2012.917          19.5                               306.59470                                9     24.98034     121.53951                        42.2
# 2      3             2013.583          13.3                               561.98450                                5     24.98746     121.54391                        47.3
# 3      4             2013.500          13.3                               561.98450                                5     24.98746     121.54391                        54.8
# ...

# %%
print(df)
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %% [markdown]
# What is Pandas?
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.

# %% [markdown]
# Pandas are also able to delete rows that are not relevant, or contains wrong values, like empty or NULL values. This is called cleaning the data.

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
df=pd.DataFrame(df)

# %%
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
print(myvar[0])
# Out:
# 1

# %%
myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
print(df.loc[0]) #loc is the method that locate the single row
# Out:
# No                                           1.00000
# X1 transaction date                       2012.91700
# X2 house age                                32.00000
# X3 distance to the nearest MRT station      84.87882
# X4 number of convenience stores             10.00000
# X5 latitude                                 24.98298
# X6 longitude                               121.54024
# Y house price of unit area                  37.90000
# Name: 0, dtype: float64

# %%
print(df.loc[[0, 4]])
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 4     24.97937     121.54245                        43.1

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows = 9999


print(df)
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# 5      6             2012.667           7.1
# 6      7             2012.667          34.5
# 7      8             2013.417          20.3
# 8      9             2013.500          31.7
# 9     10             2013.417          17.9
# 10    11             2013.083          34.8
# 11    12             2013.333           6.3
# 12    13             2012.917          13.0
# 13    14             2012.667          20.4
# 14    15             2013.500          13.2
# 15    16             2013.583          35.7
# 16    17             2013.250           0.0
# 17    18             2012.750          17.7
# 18    19             2013.417          16.9
# 19    20             2012.667           1.5
# ...

# %%
# we also read json file
# df = pd.read_json('data.json')

# %%
print(df.head())
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
print(df.tail())
# Out:
#       No  X1 transaction date  X2 house age  \
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB
# None

# %% [raw]
# Data Cleaning
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# Empty cells
# Data in wrong format
# Wrong data
# Duplicates

# %%
##Remove Rows
#One way to deal with empty cells is to remove rows that contain empty cells.
new_df=df.dropna()
print(new_df)

#Note: 
#the dropna() method returns a new DataFrame, and will not change the original.
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# 5      6             2012.667           7.1
# 6      7             2012.667          34.5
# 7      8             2013.417          20.3
# 8      9             2013.500          31.7
# 9     10             2013.417          17.9
# 10    11             2013.083          34.8
# 11    12             2013.333           6.3
# 12    13             2012.917          13.0
# 13    14             2012.667          20.4
# 14    15             2013.500          13.2
# 15    16             2013.583          35.7
# 16    17             2013.250           0.0
# 17    18             2012.750          17.7
# 18    19             2013.417          16.9
# 19    20             2012.667           1.5
# ...

# %%
# the dropna(inplace = True) will NOT return a new DataFrame, 
#but it will remove all rows containing NULL values from the original DataFrame.

#Remove all rows with NULL values:
df.dropna(inplace = True)

print(df.to_string())
# Out:
#       No  X1 transaction date  X2 house age  X3 distance to the nearest MRT station  X4 number of convenience stores  X5 latitude  X6 longitude  Y house price of unit area
# 0      1             2012.917          32.0                                84.87882                               10     24.98298     121.54024                        37.9
# 1      2             2012.917          19.5                               306.59470                                9     24.98034     121.53951                        42.2
# 2      3             2013.583          13.3                               561.98450                                5     24.98746     121.54391                        47.3
# 3      4             2013.500          13.3                               561.98450                                5     24.98746     121.54391                        54.8
# ...

# %%
#Another way of dealing with empty cells is to insert a new value instead.

#This way you do not have to delete entire rows just because of some empty cells.

#Replace Empty Values
df.fillna(150,inplace= True)

# %%
#Replace Only For Specified Columns
#The example above replaces all empty cells in the whole Data Frame.

#To only replace empty values for one column, specify the column name for the DataFrame:


df["X2 house age"].fillna(130,inplace=True)

# %%
#Replace Using Mean, Median, or Mode


#A common way to replace empty cells, 
#is to calculate the mean, median or mode value of the column.
#Pandas uses mean() median() and mode() methods to calculate the resp. values for a specified column:

x=df["X2 house age"].mean()
df["X2 house age"].fillna(x,inplace=True)

# %%
#Mean = the average value (the sum of all values divided by number of values).

#Median = the value in the middle, after you have sorted all values ascending.

#Mode = the value that appears most frequently.

# %%
x=df["X2 house age"].mode()[0]
df["X2 house age"].fillna(x,inplace=True)

# %% [markdown]
#  16        60  '2020/12/16'     98       120     215.2
#   17        60  '2020/12/17'    100       120     300.0
#   18        45  '2020/12/18'     90       112       NaN
#   19        60  '2020/12/19'    103       123     323.0
#   20        45  '2020/12/20'     97       125     243.0
#   21        60  '2020/12/21'    108       131     364.2
#   22        45           NaN    100       119     282.0
#   23        60  '2020/12/23'    130       101     300.0
#   24        45  '2020/12/24'    105       132     246.0
#   25        60  '2020/12/25'    102       126     334.5
#   26        60      20201226    100       120     250.0
#   27        60  '2020/12/27'     92       118     241.0
#   28        60  '2020/12/28'    103       132       NaN
#   29        60  '2020/12/29'    100       132     280.0
#   30        60  '2020/12/30'    102       129     380.3
#   31        60  '2020/12/31'     92       115     243.0

# %% [markdown]
# df['Date'] = pd.to_datetime(df['Date'])

# %% [raw]
#  16        60  '2020/12/16'     98       120     215.2
#   17        60  '2020/12/17'    100       120     300.0
#   18        45  '2020/12/18'     90       112       NaN
#   19        60  '2020/12/19'    103       123     323.0
#   20        45  '2020/12/20'     97       125     243.0
#   21        60  '2020/12/21'    108       131     364.2
#   22        45           NaT    100       119     282.0
#   23        60  '2020/12/23'    130       101     300.0
#   24        45  '2020/12/24'    105       132     246.0
#   25        60  '2020/12/25'    102       126     334.5
#   26        60  '2020/12/26'    100       120     250.0
#   27        60  '2020/12/27'     92       118     241.0
#   28        60  '2020/12/28'    103       132       NaN
#   29        60  '2020/12/29'    100       132     280.0
#   30        60  '2020/12/30'    102       129     380.3
#   31        60  '2020/12/31'     92       115     243.0

# %% [markdown]
# Remove rows with a NULL value in the "Date" column:
#
# df.dropna(subset=['Date'], inplace = True)

# %%
#Replacing Values
df.loc[7,'X2 house age']=45

#for x in df.index:
  #if df.loc[x, "Duration"] > 120:
    #df.loc[x, "Duration"] = 120

# %%
#Removing Rows

#for x in df.index:
    #if df.loc[x,'Duration']>45:
        #df.drop[x,inplace=True]

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %% [raw]
# Removing Duplicates
# To remove duplicates, use the drop_duplicates() method.

# %%
df.drop_duplicates(inplace=True)

# %%
df.corr()
# Out:
#                                               No  X1 transaction date  \
# No                                      1.000000            -0.048658
# X1 transaction date                    -0.048658             1.000000
# X2 house age                           -0.041278             0.022386
# X3 distance to the nearest MRT station -0.013573             0.060880
# X4 number of convenience stores        -0.012699             0.009635
# X5 latitude                            -0.010110             0.035058
# X6 longitude                           -0.011059            -0.041082
# Y house price of unit area             -0.028587             0.087491
#
#                                         X2 house age  \
# No                                         -0.041278
# X1 transaction date                         0.022386
# X2 house age                                1.000000
# X3 distance to the nearest MRT station      0.022158
# X4 number of convenience stores             0.052629
# ...

# %%
df.plot(kind = 'scatter', x = 'Y house price of unit area', y = 'X6 longitude')
plt.show()

# %%
df["X6 longitude"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>
